# %%
# !pip install mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from mplfinance) (3.10.3)
# Requirement already satisfied: pandas in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from mplfinance) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from pandas->mplfinance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from pandas->mplfinance) (2025.2)

# %%
# !pip install mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from mplfinance) (3.10.3)
# Requirement already satisfied: pandas in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from mplfinance) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from pandas->mplfinance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tourist\appdata\local\programs\python\python310\lib\site-packages (from pandas->mplfinance) (2025.2)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\tourist\AppData\Local\Programs\Python\Python313\python.exe

# %%
# !{sys.executable} -m pip install mplfinance
# Out:
# Collecting mplfinance
#   Using cached mplfinance-0.12.10b0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from mplfinance) (3.10.3)
# Requirement already satisfied: pandas in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from mplfinance) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->mplfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from pandas->mplfinance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tourist\appdata\local\programs\python\python313\lib\site-packages (from pandas->mplfinance) (2025.2)
# Using cached mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.10b0

# %%
import mplfinance as mpf
import pandas as pd

# %%
data = {
    'Date': ['2025-06-10', '2025-06-11', '2025-06-12', '2025-06-13'],
    'Open': [100, 105, 103, 108],
    'High': [110, 108, 107, 112],
    'Low': [95, 102, 100, 106],
    'Close': [108, 103, 106, 110]
}
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

mpf.plot(df, type='candle', style='charles', title='Candlestick Chart')
